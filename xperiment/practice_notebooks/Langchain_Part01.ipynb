# %%
# STEP 1: Updated Installation Instructions
# !python -m pip install -U \
  langchain \
  langchain-openai \
  langchain-community \
  langchain-core \
  langchain-cohere \
  langchain-huggingface \
  openai \
  huggingface_hub \
  cohere \
  yfinance \
  pytesseract \
  pillow \
  python-dotenv \
  ipykernel
# Out:
# Requirement already satisfied: langchain in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (1.2.6)
# Requirement already satisfied: langchain-openai in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (1.1.7)
# Requirement already satisfied: langchain-community in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (0.4.1)
# Requirement already satisfied: langchain-core in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (1.2.7)
# Requirement already satisfied: langchain-cohere in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (0.5.0)
# Requirement already satisfied: langchain-huggingface in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (1.2.0)
# Requirement already satisfied: openai in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (2.15.0)
# Requirement already satisfied: huggingface_hub in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (0.36.0)
# Collecting huggingface_hub
#   Using cached huggingface_hub-1.3.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: cohere in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (5.20.1)
# Requirement already satisfied: yfinance in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (1.0)
# Requirement already satisfied: pytesseract in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (0.3.13)
# Requirement already satisfied: pillow in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (12.1.0)
# Requirement already satisfied: python-dotenv in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (1.2.1)
# Requirement already satisfied: ipykernel in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (7.1.0)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from langchain) (1.0.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from langchain-core) (0.6.4)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from langchain-core) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from langchain-core) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from langchain-core) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.6)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.3.3)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: anyio in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (4.12.1)
# Requirement already satisfied: certifi in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from openai) (0.12.0)
# Requirement already satisfied: sniffio in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from openai) (4.67.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (1.3.1)
# Requirement already satisfied: regex>=2022.1.18 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.1.15)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from langchain-community) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from langchain-community) (2.0.46)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from langchain-community) (3.13.3)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from langchain-community) (2.2.6)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.6.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: types-pyyaml<7.0.0.0,>=6.0.12.20240917 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from langchain-cohere) (6.0.12.20250915)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from cohere) (1.12.1)
# Requirement already satisfied: tokenizers<1,>=0.15 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from cohere) (0.22.2)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from cohere) (2.32.4.20260107)
# Requirement already satisfied: filelock in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from huggingface_hub) (3.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from huggingface_hub) (2026.1.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from huggingface_hub) (1.2.0)
# Collecting shellingham (from huggingface_hub)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting typer-slim (from huggingface_hub)
#   Using cached typer_slim-0.21.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: pandas>=1.3.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from yfinance) (2.3.3)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from yfinance) (4.5.1)
# Requirement already satisfied: pytz>=2022.5 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from yfinance) (3.19.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from yfinance) (4.14.3)
# Requirement already satisfied: curl_cffi<0.14,>=0.7 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from yfinance) (6.33.4)
# Requirement already satisfied: websockets>=13.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from yfinance) (16.0)
# Requirement already satisfied: cffi>=1.12.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: appnope>=0.1.2 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from ipykernel) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from ipykernel) (1.8.19)
# Requirement already satisfied: ipython>=7.23.1 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from ipykernel) (8.38.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from ipykernel) (8.8.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from ipykernel) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from ipykernel) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from ipykernel) (7.2.1)
# Requirement already satisfied: pyzmq>=25 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from ipykernel) (6.5.4)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8.3)
# Requirement already satisfied: pycparser in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance) (3.0)
# Requirement already satisfied: decorator in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: stack_data in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: wcwidth in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from jupyter-client>=8.0.0->ipykernel) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2025.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.0.0->ipykernel) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/manyam/miniconda3/envs/poc-mode/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (0.2.3)
# Collecting click>=8.0.0 (from typer-slim->huggingface_hub)
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)

# %%
# STEP 2 — OCR System Dependency (Mac)
# !brew install tesseract
# Out:
# Warning: tesseract 5.5.2 is already installed and up-to-date.
# To reinstall 5.5.2, run:
#   brew reinstall tesseract

# %%
# STEP 3 : Import Latest Libraries 
from langchain_openai import OpenAI
from langchain_community.llms import HuggingFaceHub, Cohere
from langchain_core.prompts import PromptTemplate
from langchain_core.runnables import RunnableSequence

import yfinance as yf
import pytesseract
from PIL import Image
from IPython.display import Image as display_image

# %%
# STEP 4 : Load .env in your notebook
from dotenv import load_dotenv
import os
load_dotenv() # loads the .env file
# Out:
# True

# %%
# STEP 5 : Quick Sanity Test
llm = OpenAI()
print(llm.invoke("What do you know about LangChain?"))
# Out:
# LangChain is a blockchain platform that aims to revolutionize the translation and interpretation industry. It utilizes blockchain technology to create a secure, transparent, and decentralized network where users can easily find and hire professional translators and interpreters.
#
# The platform offers a variety of features, such as a rating system, smart contracts, and a secure payment system, to ensure high-quality and efficient translation services. It also allows users to track the progress of their translation projects in real-time and provides a secure and immutable record of all transactions.
#
# LangChain also offers its own cryptocurrency, called LANG, which can be used for payments on the platform and can also be traded on external exchanges. This provides an additional incentive for translators and interpreters to provide high-quality services and for clients to use the platform.
#
# The team behind LangChain has a strong background in both the language and blockchain industries, with a focus on creating a user-friendly and efficient platform for language services. They are also committed to promoting language diversity and cultural exchange through their platform.
#
# Overall, LangChain aims to disrupt the traditional translation industry by providing a more efficient and cost-effective solution for language services, while also promoting cross-cultural communication and understanding.
